# %%
import pandas as pd
# Out:
# C:\Users\A715-42G\AppData\Local\Temp\ipykernel_16908\4080736814.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
df = pd.read_csv('G:\My Drive\IT LOR\Phương Pháp Phát Triển Phần Mềm Hướng Đối Tượng\data_final_new.csv')
df
# Out:
#        Unnamed: 0.1  Unnamed: 0  \
# 0                 0           0
# 1                 1           1
# 2                 2           2
# 3                 3           3
# 4                 4           4
# ...             ...         ...
# 74410         74811       74811
# 74411         74812       74812
# 74412         74813       74813
# 74413         74814       74814
# 74414         74815       74815
#
#                                                    title  \
# 0      Chỉ 71tr/m có nhà 3 tầng,10x11,hẻm xe hơi Lý T...
# 1      Nhà 3 Tầng Mới Ở Ngay_ Hẻm 5m, Đs.4 Tam Phú, T...
# 2                       Cần bán nhà Hẻm Trần Hưng Đạo Q1
# 3      trệt 3 lầu , Shr Hoàn công đủ , 4pn , 4wc ,st ...
# 4      NHÀ ĐẸP DIỆN TÍCH KHỦNG 140M - TRỆT LẦU 5PN - ...
# ...                                                  ...
# 74410  Nhà 4 tầng 5pn, ngang rộng 6.3 mét hẻm oto. Sa...
# 74411  🎀 BÁN 62 CĂN HỘ RICHSTAR 1P+1P 2.4T 2PN:2.5T 3...
# ...

# %%
df.drop('Unnamed: 0',axis=1, inplace=True)
df.drop('Unnamed: 0.1',axis=1, inplace=True)

# %%
for index,row in df.iterrows():
    if isinstance(row['room_sleep'],str):
        if 'nhiều hơn 10 PN' in row['room_sleep']:
            phongngu= int(row['room_sleep'].replace('nhiều hơn ','').replace(' PN',''))
            df.loc[index,'room_sleep'] = phongngu + 1
        elif 'PN' in row['room_sleep']:
            phongngu = int(row['room_sleep'].replace(' PN',''))
            df.loc[index,'room_sleep'] = phongngu
df
# Out:
#                                                    title  \
# 0      Chỉ 71tr/m có nhà 3 tầng,10x11,hẻm xe hơi Lý T...
# 1      Nhà 3 Tầng Mới Ở Ngay_ Hẻm 5m, Đs.4 Tam Phú, T...
# 2                       Cần bán nhà Hẻm Trần Hưng Đạo Q1
# 3      trệt 3 lầu , Shr Hoàn công đủ , 4pn , 4wc ,st ...
# 4      NHÀ ĐẸP DIỆN TÍCH KHỦNG 140M - TRỆT LẦU 5PN - ...
# ...                                                  ...
# 74811  Nhà 4 tầng 5pn, ngang rộng 6.3 mét hẻm oto. Sa...
# 74812  🎀 BÁN 62 CĂN HỘ RICHSTAR 1P+1P 2.4T 2PN:2.5T 3...
# 74813  Hẽm 6m xe tải Chiến lược  Bình Trị Đông Bình T...
# 74814  MTKD 5TẦNG CÓ THANG MÁY TRƯƠNG VĨNH KÝ - 6.5*1...
# 74815  Căn hộ Golden Mansion Novaland khu sân bay giá...
#
#                                         locations room_sleep toilet  \
# 0                               phuong4_quangovap          3      3
# 1         phuongtamphuquanthuduccu_thanhphothuduc          4      2
# 2                             phuongcogiang_quan1          2      3
# ...

# %%
df['toilet'] = df['toilet'].replace('Nhiều hơn 6','7')
df
# Out:
#                                                    title  \
# 0      Chỉ 71tr/m có nhà 3 tầng,10x11,hẻm xe hơi Lý T...
# 1      Nhà 3 Tầng Mới Ở Ngay_ Hẻm 5m, Đs.4 Tam Phú, T...
# 2                       Cần bán nhà Hẻm Trần Hưng Đạo Q1
# 3      trệt 3 lầu , Shr Hoàn công đủ , 4pn , 4wc ,st ...
# 4      NHÀ ĐẸP DIỆN TÍCH KHỦNG 140M - TRỆT LẦU 5PN - ...
# ...                                                  ...
# 74811  Nhà 4 tầng 5pn, ngang rộng 6.3 mét hẻm oto. Sa...
# 74812  🎀 BÁN 62 CĂN HỘ RICHSTAR 1P+1P 2.4T 2PN:2.5T 3...
# 74813  Hẽm 6m xe tải Chiến lược  Bình Trị Đông Bình T...
# 74814  MTKD 5TẦNG CÓ THANG MÁY TRƯƠNG VĨNH KÝ - 6.5*1...
# 74815  Căn hộ Golden Mansion Novaland khu sân bay giá...
#
#                                         locations room_sleep toilet  \
# 0                               phuong4_quangovap          3      3
# 1         phuongtamphuquanthuduccu_thanhphothuduc          4      2
# 2                             phuongcogiang_quan1          2      3
# ...

# %%
df['zscore'] = (df.price - df.price.mean())/df.price.std()
df
# Out:
#                                                    title  \
# 0      Chỉ 71tr/m có nhà 3 tầng,10x11,hẻm xe hơi Lý T...
# 1      Nhà 3 Tầng Mới Ở Ngay_ Hẻm 5m, Đs.4 Tam Phú, T...
# 2                       Cần bán nhà Hẻm Trần Hưng Đạo Q1
# 3      trệt 3 lầu , Shr Hoàn công đủ , 4pn , 4wc ,st ...
# 4      NHÀ ĐẸP DIỆN TÍCH KHỦNG 140M - TRỆT LẦU 5PN - ...
# ...                                                  ...
# 74410  Nhà 4 tầng 5pn, ngang rộng 6.3 mét hẻm oto. Sa...
# 74411  🎀 BÁN 62 CĂN HỘ RICHSTAR 1P+1P 2.4T 2PN:2.5T 3...
# 74412  Hẽm 6m xe tải Chiến lược  Bình Trị Đông Bình T...
# 74413  MTKD 5TẦNG CÓ THANG MÁY TRƯƠNG VĨNH KÝ - 6.5*1...
# 74414  Căn hộ Golden Mansion Novaland khu sân bay giá...
#
#                                         locations  room_sleep  toilet  \
# 0                               phuong4_quangovap           3       3
# 1         phuongtamphuquanthuduccu_thanhphothuduc           4       2
# ...

# %%
df = df[(df.zscore>-3)&(df.zscore<3)]
df
# Out:
#                                                    title  \
# 0      Chỉ 71tr/m có nhà 3 tầng,10x11,hẻm xe hơi Lý T...
# 1      Nhà 3 Tầng Mới Ở Ngay_ Hẻm 5m, Đs.4 Tam Phú, T...
# 2                       Cần bán nhà Hẻm Trần Hưng Đạo Q1
# 3      trệt 3 lầu , Shr Hoàn công đủ , 4pn , 4wc ,st ...
# 4      NHÀ ĐẸP DIỆN TÍCH KHỦNG 140M - TRỆT LẦU 5PN - ...
# ...                                                  ...
# 74410  Nhà 4 tầng 5pn, ngang rộng 6.3 mét hẻm oto. Sa...
# 74411  🎀 BÁN 62 CĂN HỘ RICHSTAR 1P+1P 2.4T 2PN:2.5T 3...
# 74412  Hẽm 6m xe tải Chiến lược  Bình Trị Đông Bình T...
# 74413  MTKD 5TẦNG CÓ THANG MÁY TRƯƠNG VĨNH KÝ - 6.5*1...
# 74414  Căn hộ Golden Mansion Novaland khu sân bay giá...
#
#                                         locations  room_sleep  toilet  \
# 0                               phuong4_quangovap           3       3
# 1         phuongtamphuquanthuduccu_thanhphothuduc           4       2
# ...

# %%
df.to_csv('G:\My Drive\IT LOR\Phương Pháp Phát Triển Phần Mềm Hướng Đối Tượng\data_final_new.csv',index=True)
