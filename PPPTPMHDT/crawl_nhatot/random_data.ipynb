# %%
import pandas as pd
import random


# df = pd.read_csv("G:\My Drive\IT LOR\Phương Pháp Phát Triển Phần Mềm Hướng Đối Tượng\data_nhatot_new.csv")
# df2 = pd.read_csv("G:\My Drive\IT LOR\Phương Pháp Phát Triển Phần Mềm Hướng Đối Tượng\data_gop.csv")
df3 = pd.read_csv("G:\My Drive\IT LOR\Phương Pháp Phát Triển Phần Mềm Hướng Đối Tượng\data_gop.csv")
df3
# Out:
# C:\Users\A715-42G\AppData\Local\Temp\ipykernel_19400\4057777714.py:1: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd
#                                                   title  \
# 0                         Bán căn hộ vinhome grand park
# 1     Nhà Hẻm Xe Hơi Linh Chiểu- Diện Tích 76m2, 2 T...
# 2     BÁN NHÀ LINH CHIỂU ĐƯỜNG Ô TÔ NGỦ TRONG NHÀ 75...
# 3     Bán nhà mega village 5x15m=75m2 Khang Điền giá...
# 4     CHỒNG CHẤT NỢ NẦN bán nhà Quốc Lộ 13 T...
# ...                                                 ...
# 5443                       bán nhà đường 19 chợ tân quy
# ...

# %%
df_final = pd.concat([df,df2],ignore_index=True)
df_final
# Out:
#                                                    title  \
# 0                          Bán căn hộ vinhome grand park
# 1                                                 Bán că
# 2      Tặng gói thiết kế nội thất 15 triệu và 1 chỉ v...
# 3      Thanh toán 15% nhận nhà ngay 10/2024 Vinhome G...
# 4      Studio 31m2 Vinhome Grand Park - Nguyễn Xiển, ...
# ...                                                  ...
# 80611                       bán nhà đường 19 chợ tân quy
# 80612                                  Bán nhà chính chủ
# 80613  Chỉ nhận tin nhắn- không điện thoại 1.5 tỷ - B...
# 80614  CHÍNH CHỦ CẦN BÁN NHANH NHÀ LIỀN KỀ ĐÔ THỊ NAM...
# 80615  Nhà Chính Bán 1 Tỷ 360 SHR Trệt Lầu 3m10 x 4m3...
#
#                                   room               price_area  \
# 0                      1 PN - Chung cư    1,55 tỷ | 51,67 tr/m²
# 1                      1 PN - Chung cư     1,7 tỷ | 38,64 tr/m²
# 2                      1 PN - Chung cư   1,971 tỷ | 53,27 tr/m²
# ...

# %%
df = df3.sample(frac=1).reset_index(drop=True)
df
# Out:
#        Unnamed: 0.1  Unnamed: 0  \
# 0              2169         591
# 1              9217       71560
# 2              8598       64957
# 3               197        6803
# 4              4754       24791
# ...             ...         ...
# 10454          3339       11306
# 10455         10142       45119
# 10456          5262       30033
# 10457          7528       53297
# 10458          9175       70948
#
#                                                    title  \
# 0      Bán căn hộ chính chủ Melody Residencer 72m2, 2...
# 1      Cần bán căn hộ Khuông Việt, Tân Phú, 50m, 1pn,...
# 2      BÁN CĂN HỘ ORIENTAL PLAZA – ÂU CƠ, 106M 3PN 2W...
# 3      💥 Hot! Celadon Diamond 3PN/2PN giá chỉ tù 7 tỷ...
# 4      ❣️ Bán căn hộ The Park Residence 2pn - 1wc vie...
# ...                                                  ...
# 10454  BÁN PRECIA 3PN, ĐÃ CÓ SỔ AN TÂM AN CƯ LẠC NGHI...
# 10455                                        Bán nhà phố
# ...

# %%
# Lưu lại file CSV đã trộn
df.to_csv("G:\My Drive\IT LOR\Phương Pháp Phát Triển Phần Mềm Hướng Đối Tượng\data_chung_cu.csv", index=False)

# %%
# Out:
# Empty DataFrame
# Columns: [title, room, price_area, location, district, toilet]
# Index: []
